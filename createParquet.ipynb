# %%
import pandas as pd

# %%
df = pd.read_csv("AwardNomination.csv")

# %%
df = pd.read_csv("query_result.csv",sep='|')

# %%
df
# Out:
#           id  idawardtype  winner                         category
# 0      10347           93    True              b'best music score'
# 1      15774          219    True              b'best music score'
# 2      54909          845    True              b'best music score'
# 3      54910          845    True              b'best music score'
# 4      54919          845    True              b'best music score'
# ...      ...          ...     ...                              ...
# 1248  389696         5047    True           b'best original score'
# 1249  390335         5047    True  b'best score comedy or musical'
# 1250  390340         5047    True              b'best score drama'
# 1251  390398         5047    True  b'best score comedy or musical'
# 1252  390403         5047    True              b'best score drama'
#
# [1253 rows x 4 columns]

# %%
df.to_csv("AwardNomination.csv",sep='|',index=False)

# %%
df.to_parquet("AwardNomination.parquet")

# %%
pd.read_parquet("AwardNomination.parquet")
# Out:
#             ID  IDAwardType  Winner             Category
# 0         1495           45    True       cinematography
# 1         1547           34    True      best screenplay
# 2         1548           34    True      best screenplay
# 3         1598           34   False  best cinematography
# 4         1690           34   False  best cinematography
# ...        ...          ...     ...                  ...
# 248768  390413         5047   False    best sound design
# 248769  390414         5047   False    best sound design
# 248770  390415         5047    True  best visual effects
# 248771  390416         5047   False  best visual effects
# 248772  390417         5047   False  best visual effects
#
# [248773 rows x 4 columns]

# %%
df[df.ID>13558]
# Out:
#             ID  IDAwardType  Winner                           Category
# 1016     13559          159    True  best western drama script fiction
# 1017     13560          159    True  best western drama script fiction
# 1018     13561          159   False  best western drama script fiction
# 1019     13563          159    True  best western drama script fiction
# 1020     13564          159    True  best western drama script fiction
# ...        ...          ...     ...                                ...
# 248768  390413         5047   False                  best sound design
# 248769  390414         5047   False                  best sound design
# 248770  390415         5047    True                best visual effects
# 248771  390416         5047   False                best visual effects
# 248772  390417         5047   False                best visual effects
#
# [243792 rows x 4 columns]

# %%
df.Category = df.Category.str.encode('utf-8')

# %%
df.
# Out:
# ID                              363173
# IDAwardType                       4932
# Winner                           False
# Category       best screenplay adapted
# Name: 31364, dtype: object
